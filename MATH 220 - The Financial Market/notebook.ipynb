# %% [markdown]
# **GROUP 1 MEMBERS**
# * 10712524
# * 10808843
# * 10811846

# %% [markdown]
# # Financial Market And The Crypto Market

# %% [markdown]
# ## Financial Market

# %% [markdown]
# Financial markets refer broadly to any marketplace where the trading of securities occurs, including the stock market, bond market, forex market, and derivatives market, among others.
#
# Types of Financial Markets
# *  Stock Market
# *  Forex Market
# *  Commodities Markets
# *  Cryptocurrency Markets
# *  Bond Market

# %%
# %pylab inline
import pandas as pd
import seaborn as sns


import matplotlib.patches as mpatches
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Loading of Images
from PIL import Image

location1= r"/work/XImages/402022.image0[1].jpg"
# Price Chart
img1 = Image.open(location1)


location2= r"/work/XImages/The-trends.jpg"
# Trend
img2 = Image.open(location2)


location3= r"/work/XImages/real MA.PNG"
# Trend
img3 = Image.open(location3)

loc4 = r"/work/XImages/real std.PNG"
img4 = Image.open(loc4)

# %% [markdown]
# ## Loading Data

# %%
#Load Dataset
btc_df = pd.read_csv("Bitcoin.csv")
ltc_df = pd.read_csv("Litecoin.csv")
etc_df = pd.read_csv("Ethereum.csv")
etc_cl_df = pd.read_csv("/work/Ethereum Classic.csv")
doge = pd.read_csv("/work/Meme Coin/Dogecoin.csv")
xcoin_df = pd.read_csv("/work/Meme Coin/100xcoins.csv")
akita_df = pd.read_csv("/work/Meme Coin/Akita Inu.csv")
chow = pd.read_csv("/work/Meme Coin/Chow Chow.csv")
cum = pd.read_csv("/work/Meme Coin/Cumrocket Crypto.csv")
doge = pd.read_csv("/work/Meme Coin/Dogecoin.csv")
dogelon_Mars = pd.read_csv("/work/Meme Coin/Dogelon Mars.csv")
Elongate = pd.read_csv("/work/Meme Coin/Elongate.csv")
Dataset = pd.read_csv("Dataset.csv")
Dataset_Open = pd.read_csv("/work/Dataset_Open.csv")
book1 = pd.read_csv("/work/Book12.csv")

# %% [markdown]
# ##  Dataset

# %% [markdown]
# * Data is returned in descending order. Recent first, oldest last.
# * Date, Open, High, Low, Close, Volume and  Market Cap
# * Open price is the price at which a security first trades upon the opening of an exchange on a trading day
# * Close refers to the last price at which a security trades during a regular trading session
# * High is the highest price at which a security trades during a regular trading session
# * Low is the lowest price at which a security trades during a regular trading session

# %% [markdown]
# # Cryptocurrencies  Based on Dataset

# %% [markdown]
# Based on our dataset the types of cryptocurrency are:
# * Major Coins (Bitcoin, Ethereum, Litecoin, Dogecoin)
# * Dead Coin
# * Meme Coin
# * Penny Coin

# %% [markdown]
# ## What are Dead Coins?

# %% [markdown]
# Dead Coins refer to cryptocurrencies that have been abandoned, used as scam, their website is down, has no nodes, has wallet issues, doesn't have social updates, has low volume or developers have walked away from the project.Examples are:
# * Aeron
# * 0xBitcoin
# * Bitconnect
# * Storeum
# * Vegas Coin

# %% [markdown]
# # What are Meme Coins?

# %% [markdown]
# Meme coins are cryptocurrencies that have gained popularity in a short amount of time, usually as a result of influencers and retail investors promoting them online.
#
# Dogecoin is the original meme coin: It was created as a joke based on a meme back in 2013. It rose to fame after Elon Musk began tweeting about the cryptocurrency, and retail investors started buying in droves.
#
# Because anybody can create a new cryptocurrency, developers have released a slew of meme coins after Dogecoin. Many of these coins are spinoffs of Dogecoin -- take the coin Shiba Inu (CRYPTO:SHIB), for example -- but there are thousands of other meme coins out there. In fact, according to the website CoinMarketCap, there are more than 5,000 meme coins in existence as of this writing.

# %% [markdown]
# # What are Penny Coins?

# %% [markdown]
# As the name suggests, penny cryptocurrencies are digital assets that are worth less than $1. If you analyze the crypto market, you’ll quickly realize that most of the cryptocurrencies available for purchase are penny cryptos.

# %% [markdown]
# # Graph

# %% [markdown]
# *  Line Charts
# *  Scatter Plot

# %% [markdown]
# ## Line Charts

# %% [markdown]
# The line for market price always consist of price against time.
#
# At any point in time, the line chart allows one to plot a single  variable against time.
# One can plot any of these variables with to:
#
# *  Open
# *  Close
# *  High
# *  Low

# %%
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=417x400>

# %% [markdown]
# ## Trend (Direction of Market)

# %% [markdown]
# Trend Of Market
#
# A trend is the overall direction of a market or an asset's price. In technical analysis, trends are identified by trendlines or price action that highlight when the price is making higher swing highs and higher swing lows for an uptrend, or lower swing lows and lower swing highs for a downtrend.

# %%
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=845x364>

# %% [markdown]
# ## Exploring Dataset

# %% [markdown]
# ## Open Price

# %%
figure(figsize= (20,10))
plot(btc_df["Open"],'k',label = "BTC");

title("Closing Values of BTC")

yscale("log")

xticks([2958, 2500, 2000, 1500,1000,  500, 0],
 ['28-04-2013','30-07-2014','12-12-2015', '25-04-2017','07-09-2018', '20-01-2020', '03-06-2021' ])

# 
gca().invert_xaxis()
legend(loc = "upper left")

# %%
print(btc_df.head())
# Out:
#          Date          Open          High           Low         Close  \
# 0  27-06-2021  32287.523211  34656.127356  32071.757148  34649.644588
# 1  26-06-2021  31594.663571  32637.587193  30184.501794  32186.277671
# 2  25-06-2021  34659.104499  35487.248003  31350.883858  31637.780055
# 3  24-06-2021  33682.800404  35228.852611  32385.214696  34662.435894
# 4  23-06-2021  32515.714303  34753.408503  31772.632355  33723.028978
#
#          Volume    Market Cap
# 0  3.551164e+10  6.494617e+11
# 1  3.858539e+10  6.032760e+11
# 2  4.023090e+10  5.929782e+11
# 3  3.312337e+10  6.496440e+11
# 4  4.631711e+10  6.320113e+11

# %% [markdown]
# ## Closing Price

# %%
figure(figsize= (20,10))
subplot()

plot(btc_df["Close"],'r',label = "LTC");



title("Closing Price of  LTC")
yscale("log")
xticks([2958, 2500, 2000, 1500,1000,  500, 0],
 ['28-04-2013','30-07-2014','12-12-2015', '25-04-2017','07-09-2018', '20-01-2020', '03-06-2021' ])
gca().invert_xaxis()
legend(loc = "upper left")

# %% [markdown]
# ## Moving Averages

# %% [markdown]
# The moving average (MA) is a simple technical analysis tool that smooths out price data by creating a constantly updated average price. The average is taken over a specific period of time, like 10 days, 20 minutes, 30 weeks or any time period the trader chooses.

# %% [markdown]
# ## Simple Moving Average

# %% [markdown]
# Simple Moving Average (SMA)
# Simple, in other words, arithmetical moving average is calculated by summing up the prices of instrument closure over a certain number of single periods (for instance, 12 hours). This value is then divided by the number of such periods.
#
# SMA = SUM (CLOSE (i), N) / N
#
# Where:
#
# SUM — sum;
#
# CLOSE (i) — current period close price;
#
# N — number of calculation periods.

# %% [markdown]
# ## Demo

# %%
img3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=309x449>

# %%
# Caculation of  SMA

btc_df["200 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 200).mean()
btc_df["160 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 160).mean()
btc_df["140 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 140).mean()
btc_df["120 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 120).mean()
btc_df["100 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 100).mean()
btc_df["80 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 80).mean()
btc_df["60 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 60).mean()
btc_df["40 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 40).mean()
btc_df["30 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 20).mean()
btc_df["25 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 25).mean()
btc_df["20 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 20).mean()
btc_df["15 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 15).mean()
btc_df["10 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 10).mean()
btc_df["5 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 5).mean()
btc_df["3 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 3).mean()

ltc_df["200 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 200).mean()
ltc_df["160 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 160).mean()
ltc_df["140 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 140).mean()
ltc_df["120 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 120).mean()
ltc_df["100 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 100).mean()
ltc_df["80 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 80).mean()
ltc_df["60 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 60).mean()
ltc_df["40 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 40).mean()
ltc_df["30 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 20).mean()
ltc_df["25 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 25).mean()
ltc_df["20 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 20).mean()
ltc_df["15 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 15).mean()
ltc_df["10 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 10).mean()
ltc_df["5 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 5).mean()
ltc_df["3 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 3).mean()

etc_df["200 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 200).mean()
etc_df["160 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 160).mean()
etc_df["140 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 140).mean()
etc_df["120 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 120).mean()
etc_df["100 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 100).mean()
etc_df["80 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 80).mean()
etc_df["60 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 60).mean()
etc_df["40 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 40).mean()
etc_df["30 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 20).mean()
etc_df["25 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 25).mean()
etc_df["20 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 20).mean()
etc_df["15 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 15).mean()
etc_df["10 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 10).mean()
etc_df["5 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 5).mean()
etc_df["3 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 3).mean()

# %% [markdown]
# ## Nature of  Dynamic Moving Average

# %% [markdown]
# # Simple Moving Average For Bitcoin, Lite coin and Ethereum

# %%
figure(figsize= (20,15))
plot(btc_df["200 SMA"], label= "200 SMA", color= "red")
plot(btc_df["160 SMA"], label= "160 SMA", color= "blue")
plot(btc_df["140 SMA"], label= "140 SMA", color = "violet")

plot(btc_df["120 SMA"], label= "120 SMA", color = "darkgoldenrod"  )
plot(btc_df["100 SMA"], label= "100 SMA", color = "darkslategray" )
plot(btc_df["80 SMA"], label= "80 SMA", color ="forestgreen" )

plot(btc_df["60 SMA"], label= "60 SMA", color = "limegreen" )
plot(btc_df["40 SMA"], label= "400 SMA", color = "seagreen" )
plot(btc_df["30 SMA"], label= "300 SMA", color = "darkcyan" )

plot(btc_df["25 SMA"], label= "25 SMA", color = "darkmagenta")
plot(btc_df["20 SMA"], label= "20 SMA", color = "crimson" )
plot(btc_df["15 SMA"], label= "15 SMA", color = "orchid")

plot(btc_df["10 SMA"], label= "10 SMA", color = "palegreen" )
plot(btc_df["5 SMA"], label= "5 SMA", color = "khaki" )
plot(btc_df["3 SMA"], label= "3 SMA", color = "lime")

plot(btc_df["Close"], label = "Close", color = "black")
title("BTC Closing Price and Moving Averages", fontdict = {'fontname':'Comic Sans MS', 'fontsize': 20})

xticks([2958, 2500, 2000, 1500,1000,  500, 0],
 ['28-04-2013','30-07-2014','12-12-2015', '25-04-2017','07-09-2018', '20-01-2020', '03-06-2021' ])

xlim(100, 800)
ylim(3300,100000)


yscale("log")
gca().invert_xaxis()

legend()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
figure(figsize= (20,15))
plot(ltc_df["200 SMA"], label= "200 SMA", color= "red")
plot(ltc_df["160 SMA"], label= "160 SMA", color= "blue")
plot(ltc_df["140 SMA"], label= "140 SMA", color = "violet")

plot(ltc_df["120 SMA"], label= "120 SMA", color = "darkgoldenrod"  )
plot(ltc_df["100 SMA"], label= "100 SMA", color = "darkslategray" )
plot(ltc_df["80 SMA"], label= "80 SMA", color ="forestgreen" )

plot(ltc_df["60 SMA"], label= "60 SMA", color = "limegreen" )
plot(ltc_df["40 SMA"], label= "400 SMA", color = "seagreen" )
plot(ltc_df["30 SMA"], label= "300 SMA", color = "darkcyan" )

plot(ltc_df["25 SMA"], label= "25 SMA", color = "darkmagenta")
plot(ltc_df["20 SMA"], label= "20 SMA", color = "crimson" )
plot(ltc_df["15 SMA"], label= "15 SMA", color = "orchid")

plot(ltc_df["10 SMA"], label= "10 SMA", color = "palegreen" )
plot(ltc_df["5 SMA"], label= "5 SMA", color = "khaki" )
plot(ltc_df["3 SMA"], label= "3 SMA", color = "lime")

plot(ltc_df["Close"], label = "Close", color = "black")
title("LTC Closing Price and Moving Averages", fontdict = {'fontname':'Comic Sans MS', 'fontsize': 20})

xticks([2958, 2500, 2000, 1500,1000,  500, 0],
 ['28-04-2013','30-07-2014','12-12-2015', '25-04-2017','07-09-2018', '20-01-2020', '03-06-2021' ])

xlim(100, 1000)
ylim(30,200)

yscale("log")
gca().invert_xaxis()

legend()

# %%
figure(figsize= (20,15))
plot(etc_df["200 SMA"], label= "200 SMA", color= "red")
plot(etc_df["160 SMA"], label= "160 SMA", color= "blue")
plot(etc_df["140 SMA"], label= "140 SMA", color = "violet")

plot(etc_df["120 SMA"], label= "120 SMA", color = "darkgoldenrod"  )
plot(etc_df["100 SMA"], label= "100 SMA", color = "darkslategray" )
plot(etc_df["80 SMA"], label= "80 SMA", color ="forestgreen" )

plot(etc_df["60 SMA"], label= "60 SMA", color = "limegreen" )
plot(etc_df["40 SMA"], label= "400 SMA", color = "seagreen" )
plot(etc_df["30 SMA"], label= "300 SMA", color = "darkcyan" )

plot(etc_df["25 SMA"], label= "25 SMA", color = "darkmagenta")
plot(etc_df["20 SMA"], label= "20 SMA", color = "crimson" )
plot(etc_df["15 SMA"], label= "15 SMA", color = "orchid")

plot(etc_df["10 SMA"], label= "10 SMA", color = "palegreen" )
plot(etc_df["5 SMA"], label= "5 SMA", color = "khaki" )
plot(etc_df["3 SMA"], label= "3 SMA", color = "lime")

plot(etc_df["Close"], label = "Close", color = "black")
title("ETC Closing Price and Moving Averages", fontdict = {'fontname':'Comic Sans MS', 'fontsize': 20})

xticks([2958, 2500, 2000, 1500,1000,  500, 0],
 ['28-04-2013','30-07-2014','12-12-2015', '25-04-2017','07-09-2018', '20-01-2020', '03-06-2021' ])

xlim(220, 1200)
ylim(70,2000)

yscale("log")
gca().invert_xaxis()

legend()

# %% [markdown]
# ## Observation

# %%
figure(figsize= (20,10))
plot(btc_df["200 SMA"], label= "200 SMA", color= "red")
plot(btc_df["160 SMA"], label= "160 SMA", color= "blue")
plot(btc_df["140 SMA"], label= "140 SMA", color = "violet")


plot(btc_df["60 SMA"], label= "60 SMA" )
plot(btc_df["40 SMA"], label= "40 SMA" )
plot(btc_df["30 SMA"], label= "30 SMA")

plot(btc_df["Close"], label = "Close", color = "black")
title("BTC Closing Price and Moving Averages")

yscale("log")

xlim(0, 1000)
ylim(4000,100000)


xticks([2958, 2500, 2000, 1500,1000,  500, 0],
  ['28-04-2013','30-07-2014','12-12-2015', '25-04-2017',
   '07-09-2018', '20-01-2020', '03-06-2021' ])

gca().invert_xaxis()

annotate('Long Term Trend', xy=(200, 12000),  xycoords='data',
            xytext=(50, 6500) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )      

annotate('Medium Term Trend', xy=(150, 25000),  xycoords='data',
            xytext=(30, 8900) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )               
      

legend()

# %% [markdown]
# ## Plot for Long, Medium and  Low MA

# %%
figure(figsize= (20,10))
plot(btc_df["200 SMA"], label= "200 SMA", color= "red")
plot(btc_df["60 SMA"], label= "60 SMA", color= "blue")
plot(btc_df["10 SMA"], label= "10 SMA", color = "orchid")

plot(btc_df["Close"], label = "Close", color = "black")
title("BTC Closing Price and Moving Averages")

xticks([2958, 2500, 2000, 1500,1000,  500, 0],
 ['28-04-2013','30-07-2014','12-12-2015', '25-04-2017','07-09-2018', '20-01-2020', '03-06-2021' ])

xlim(0, 500)
ylim(2200,70000)
yscale("log")
gca().invert_xaxis()

legend()

# %% [markdown]
# # Strategies

# %% [markdown]
# ## Medium Term Traders(Swing Traders)

# %% [markdown]
# ## Price Crossover Strat

# %%
figure(figsize= (20,10))

btc_df["50 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 50).mean()
plot(btc_df["Close"], label = "Close", color = "black")
plot(btc_df["50 SMA"], label= "50 SMA", color= "red")

title("BTC Closing Price and Moving Averages", fontdict = {'fontname':'Comic Sans MS', 'fontsize': 20})
xlim(1000, 2500)

yscale("log")

# xticks([2958, 2500, 2000, 1500,1000,  500, 0],
#  ['28-04-2013','30-07-2014','12-12-2015', '25-04-2017',
#   '07-09-2018', '20-01-2020', '03-06-2021' ])

xlim(0,1000)
ylim(10**3, 10**5)
gca().invert_xaxis()
legend(loc = "upper left")

legend()


annotate('SELL', xy=(480, 10000),  xycoords='data',
            xytext=(560, 20000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )

annotate('SELL', xy=(720, 14000),  xycoords='data',
            xytext=(790, 35000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )

annotate('SELL', xy=(620, 10000),  xycoords='data',
            xytext=(710, 33000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )


annotate('SELL', xy=(130, 66000),  xycoords='data',
            xytext=(200, 70000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )


annotate('BUY', xy=(320, 9500),  xycoords='data',
            xytext=(400, 6500) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )      

annotate('BUY', xy=(880, 3000),  xycoords='data',
            xytext=(800, 1500) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )
# Out:
# Text(800, 1500, 'BUY')

# %%
figure(figsize= (20,15))

etc_df["50 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 50).mean()
plot(etc_df["Close"], label = "Close", color = "black")
plot(etc_df["50 SMA"], label = "Close", color = "red")


title("ETC Closing Price and Moving Averages", fontdict = {'fontname':'Comic Sans MS', 'fontsize': 20})
xlim(1000, 2200)
# ylim(100,1000)

yscale("log")
gca().invert_xaxis()

legend()


# annotate('SELL', xy=(620, 10000),  xycoords='data',
#             xytext=(710, 33000) ,
#             arrowprops=dict(facecolor='black'),
#             horizontalalignment='right', verticalalignment='top',
#             )


# annotate('SELL', xy=(130, 66000),  xycoords='data',
#             xytext=(200, 70000) ,
#             arrowprops=dict(facecolor='black'),
#             horizontalalignment='right', verticalalignment='top',
#             )



annotate('BUY', xy=(1630, 6.9),  xycoords='data',
            xytext=(1400, 2) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )


annotate('BUY', xy=(1870, 8),  xycoords='data',
            xytext=(1600, 2) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )


annotate('BUY', xy=(1760, 10),  xycoords='data',
            xytext=(1500, 2) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )


annotate('SELL', xy=(1710, 15),  xycoords='data',
            xytext=(1560, 56) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )

annotate('SELL', xy=(1790, 15),  xycoords='data',
            xytext=(1660, 56) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )


annotate('SELL', xy=(1920, 15),  xycoords='data',
            xytext=(2000, 56) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )



annotate('SELL', xy=(1820, 15),  xycoords='data',
            xytext=(1780, 56) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )

left, bottom, width, height = (1470, 5, 600, 20)
rect=mpatches.Rectangle((left,bottom),width,height, 
                        fill=False,
                        color="orchid",
                       linewidth=2)
                       #facecolor="red")

gca().add_patch(rect)
legend()

# %%
figure(figsize= (20,15))

ltc_df["50 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 50).mean()
plot(ltc_df["Close"], label = "Close", color = "black")
plot(ltc_df["50 SMA"], label = "Close", color = "red")


title("LTC Closing Price and Moving Averages", fontdict = {'fontname':'Comic Sans MS', 'fontsize': 20})
xlim(1000, 2500)
# ylim(100,1000)

yscale("log")
gca().invert_xaxis()



annotate('SELL', xy=(2090, 2.6),  xycoords='data',
            xytext=(1960, 1) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )

annotate('SELL', xy=(2030, 3.2),  xycoords='data',
            xytext=(1860, 1) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )   

annotate('SELL', xy=(1930, 3.2),  xycoords='data',
            xytext=(1800, 1) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )   


annotate('SELL', xy=(1900, 3.2),  xycoords='data',
            xytext=(1770, 1) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )   


annotate('SELL', xy=(1760, 3.2),  xycoords='data',
            xytext=(1600, 1) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )   

annotate('SELL', xy=(1690, 3.2),  xycoords='data',
            xytext=(1550, 1) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )   


annotate('SELL', xy=(1690, 4.2),  xycoords='data',
            xytext=(1550, 14) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )   


annotate('SELL', xy=(1830, 4.8),  xycoords='data',
            xytext=(1650, 14) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )   

annotate('SELL', xy=(2010, 3.8),  xycoords='data',
            xytext=(1750, 14) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )   

annotate('SELL', xy=(2130, 4.3),  xycoords='data',
            xytext=(1950, 14) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )   

left, bottom, width, height = (1570, 2, 610, 5)
rect=mpatches.Rectangle((left,bottom),width,height, 
                        fill=False,
                        color="orchid",
                       linewidth=2)
                       #facecolor="red")

gca().add_patch(rect)
legend()

# %% [markdown]
# ## Two Period Moving Average Cross Over

# %%
btc_df["50 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 50).mean()
btc_df["20 SMA"] = btc_df["Close"].iloc[::-1].rolling(window= 20).mean()


figure(figsize= (20,10))

plot(btc_df["50 SMA"], label= "50 SMA", color= "red") 
plot(btc_df["20 SMA"], label= "20 SMA")


plot(btc_df["Close"], label = "Close", color = "black")
title("BTC Closing Price and 50 SMA")

yscale("log")


xlim(0, 1000)
ylim(1000)

gca().invert_xaxis()
# xlim(0,1000)
legend(loc = "upper left")


annotate('SELL', xy=(530, 10000),  xycoords='data',
            xytext=(600, 20000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )

annotate('SELL', xy=(720, 14000),  xycoords='data',
            xytext=(790, 35000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )

annotate('SELL', xy=(130, 66000),  xycoords='data',
            xytext=(200, 70000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )


annotate('BUY', xy=(320, 9500),  xycoords='data',
            xytext=(400, 6500) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )      

annotate('BUY', xy=(880, 3000),  xycoords='data',
            xytext=(800, 1500) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )
# Out:
# Text(800, 1500, 'BUY')

# %%
figure(figsize= (20,15))

etc_df["50 SMA"] = etc_df["Close"].iloc[::-1].rolling(window= 50).mean()
plot(etc_df["Close"], label = "Close", color = "black")
plot(etc_df["50 SMA"], label = "Close", color = "red")
plot(etc_df["20 SMA"], label = "Close", color = "blue")


title("ETC Closing Price and Moving Averages", fontdict = {'fontname':'Comic Sans MS', 'fontsize': 20})
xlim(1000, 2200)
# ylim(100,1000)

yscale("log")
gca().invert_xaxis()

legend()


annotate('SELL', xy=(480, 10000),  xycoords='data',
            xytext=(560, 20000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )

annotate('SELL', xy=(720, 14000),  xycoords='data',
            xytext=(790, 35000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )

annotate('SELL', xy=(620, 10000),  xycoords='data',
            xytext=(710, 33000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )



# hjk

annotate('BUY', xy=(1630, 6.9),  xycoords='data',
            xytext=(1400, 2) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )




annotate('BUY', xy=(1760, 10),  xycoords='data',
            xytext=(1500, 2) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )


annotate('SELL', xy=(1710, 15),  xycoords='data',
            xytext=(1560, 56) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )




annotate('SELL', xy=(1820, 15),  xycoords='data',
            xytext=(1780, 56) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )

left, bottom, width, height = (1470, 5, 600, 20)
rect=mpatches.Rectangle((left,bottom),width,height, 
                        fill=False,
                        color="orchid",
                       linewidth=2)
                       #facecolor="red")

gca().add_patch(rect)
legend()

# %%
figure(figsize= (20,15))

ltc_df["50 SMA"] = ltc_df["Close"].iloc[::-1].rolling(window= 50).mean()
plot(ltc_df["Close"], label = "Close", color = "black")
plot(ltc_df["50 SMA"], label = "Close", color = "red")
plot(ltc_df["20 SMA"], label = "Close", color = "blue")



title("LTC Closing Price and Moving Averages", fontdict = {'fontname':'Comic Sans MS', 'fontsize': 20})
xlim(1000, 2500)
# ylim(100,1000)

yscale("log")
gca().invert_xaxis()



annotate('SELL', xy=(2090, 2.6),  xycoords='data',
            xytext=(1960, 1) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )


annotate('SELL', xy=(1760, 3.2),  xycoords='data',
            xytext=(1600, 1) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )   


annotate('SELL', xy=(1830, 4.8),  xycoords='data',
            xytext=(1650, 14) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )   

annotate('SELL', xy=(2010, 3.8),  xycoords='data',
            xytext=(1750, 14) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )   

annotate('SELL', xy=(2130, 4.3),  xycoords='data',
            xytext=(1950, 14) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )   

left, bottom, width, height = (1570, 2, 610, 5)
rect=mpatches.Rectangle((left,bottom),width,height, 
                        fill=False,
                        color="orchid",
                       linewidth=2)
                       #facecolor="red")

gca().add_patch(rect)
legend()

# %% [markdown]
# # Bollinger  Band Bounce

# %% [markdown]
# A Bollinger Band is a technical analysis tool defined by a set of trendlines plotted two standard deviations (positively and negatively) away from a simple moving average (SMA) of a security’s price, but which can be adjusted to user preferences.

# %% [markdown]
# ## Demonstration

# %%
#Calculaion of Boliinger Bands
btc_df['TP'] = (btc_df['Close'] + btc_df['Low'] + btc_df['High'])/3
btc_df['std'] = btc_df['TP'].rolling(20).std()
btc_df['Moving Average'] = btc_df['TP'].rolling(20).mean()
btc_df['Upper Band'] = btc_df['Moving Average'] + 2*btc_df['std'] 
btc_df['Lower Band'] = btc_df['Moving Average'] - 2*btc_df['std']

# %%
img4
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1088x485>

# %%
#Calculaion of Boliinger Bands
ltc_df['TP'] = (ltc_df['Close'] + ltc_df['Low'] + ltc_df['High'])/3
ltc_df['std'] = ltc_df['TP'].rolling(20).std()
ltc_df['Moving Average'] = ltc_df['TP'].rolling(20).mean()
ltc_df['Upper Band'] = ltc_df['Moving Average'] + 2*ltc_df['std'] 
ltc_df['Lower Band'] = ltc_df['Moving Average'] - 2*btc_df['std']

# %%
figure(figsize= (15,10))
plot(btc_df["Close"], label = "Close", color = "black")
plot(btc_df["Upper Band"], label = "Upper Band", color = "orange")
plot(btc_df["Lower Band"], label = "Lower Band", color = "blue")


xlim(0, 250)
# ylim(9000, 80000)

gca().invert_xaxis()
legend(loc = "upper left")

fill_between(btc_df.index, btc_df['Upper Band'], btc_df['Lower Band'], facecolor='orange', alpha=0.1)

# %%
figure(figsize= (15,10))
plot(btc_df["Close"], label = "Close", color = "black")
plot(btc_df["Upper Band"], label = "Upper Band", color = "orange")
plot(btc_df["Lower Band"], label = "Lower Band", color = "blue")


xlim(0, 250)
ylim(9000, 80000)

gca().invert_xaxis()
legend(loc = "upper left")

fill_between(btc_df.index, btc_df['Upper Band'], btc_df['Lower Band'], facecolor='orange', alpha=0.1)


annotate('SELL', xy=(130, 60000),  xycoords='data',
            xytext=(150, 70000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )

annotate('SELL', xy=(104, 62000),  xycoords='data',
            xytext=(70, 76000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )            

annotate('SELL', xy=(68, 64000),  xycoords='data',
            xytext=(40, 76000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )          


annotate('SELL', xy=(46, 64000),  xycoords='data',
            xytext=(20, 76000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )            
            

annotate('BUY', xy=(125, 42000),  xycoords='data',
            xytext=(140, 30000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )

annotate('BUY', xy=(89, 50000),  xycoords='data',
            xytext=(70, 40000) ,
            arrowprops=dict(facecolor='black'),
            horizontalalignment='right', verticalalignment='top',
            )
# Out:
# Text(70, 40000, 'BUY')

# %% [markdown]
# # Correlation between Close Values of BTC, LTC and ETH

# %%
Correlation_dataset = Dataset.corr()
Correlation_dataset
# Out:
#           BTC        LTC       ETC
# BTC   1.000000  0.717343  0.318168
# LTC   0.717343  1.000000  0.774190
# ETC   0.318168  0.774190  1.000000

# %%
sns.heatmap(Correlation_dataset,cmap = 'Blues', annot= True)

sns.set(rc={'figure.figsize':(15,8.27)})

# %%
Correlation_book1 = book1.corr()
Correlation_book1
# Out:
#                       Bsic Attention Token    Chiliz  Holochain   Polygon  \
# Bsic Attention Token              1.000000  0.947928   0.917765  0.622533
# Chiliz                            0.947928  1.000000   0.903498  0.642198
# Holochain                         0.917765  0.903498   1.000000  0.609586
# Polygon                           0.622533  0.642198   0.609586  1.000000
# Raven Coin                        0.901997  0.885861   0.813676  0.467941
# Stellar Lumen                     0.774680  0.811708   0.700887  0.649486
# VeChain                           0.920995  0.891423   0.878345  0.733711
# Zilliqa                           0.852817  0.900572   0.760192  0.617442
#
#                       Raven Coin  Stellar Lumen   VeChain   Zilliqa
# Bsic Attention Token    0.901997       0.774680  0.920995  0.852817
# Chiliz                  0.885861       0.811708  0.891423  0.900572
# Holochain               0.813676       0.700887  0.878345  0.760192
# ...

# %%
sns.heatmap(Correlation_book1,cmap = 'rocket_r', annot= True)
sns.set(rc={'figure.figsize':(15,8.27)})

# %% [markdown]
# ## Conclusion

# %% [markdown]
# * Moving Averages between 150 and 200 are good for determining long term trend, 60 and 30 are excellent for finding medium term trend and 3 to 10 for short term.
# We came to this conclusion by studing how the MA responded to the trend
# * The single moving average could determine just the trend and not suitable for the entries
# * The double moving average is better for entries
# * Bollinger Bands good for choppy market
